# %% [markdown]
# <a href="https://colab.research.google.com/github/Nirmal456/Machine-Learning-labs/blob/main/Lab_7_AP23110010200.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets

# For handling data
import pandas as pd
import numpy as np

# %%
# !gdown 1ZdhRqYv-JizWV6DxO6C4R_k1kxPhmlF2
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZdhRqYv-JizWV6DxO6C4R_k1kxPhmlF2
# To: /content/multiclass.csv
# 100% 14.6k/14.6k [00:00<00:00, 26.5MB/s]

# %%
from sklearn import datasets

# For handling data
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/multiclass.csv')
display(df.head())
# Out:
#    Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen  class
# 0       3  12669  9656     7561     214              2674        1338      2
# 1       3   7057  9810     9568    1762              3293        1776      2
# 2       3   6353  8808     7684    2405              3516        7844      2
# 3       3  13265  1196     4221    6404               507        1788      1
# 4       3  22615  5410     7198    3915              1777        5185      1

# %%
# Check for null values
print("Null values:")
print(df.isnull().sum())
# Out:
# Null values:
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# class               0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# Separate features and target
X = df.drop('class', axis=1)
y = df['class']

# Initialize the scaler
scaler = StandardScaler()

# Fit and transform the features
X_scaled = scaler.fit_transform(X)

# Convert back to a DataFrame for easier viewing (optional)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

display(X_scaled_df.head())
# Out:
#      Region     Fresh      Milk   Grocery    Frozen  Detergents_Paper  \
# 0  0.590668  0.052933  0.523568 -0.041115 -0.589367         -0.043569
# 1  0.590668 -0.391302  0.544458  0.170318 -0.270136          0.086407
# 2  0.590668 -0.447029  0.408538 -0.028157 -0.137536          0.133232
# 3  0.590668  0.100111 -0.624020 -0.392977  0.687144         -0.498588
# 4  0.590668  0.840239 -0.052396 -0.079356  0.173859         -0.231918
#
#    Delicassen
# 0   -0.066339
# 1    0.089151
# 2    2.243293
# 3    0.093411
# 4    1.299347

# %%
print("Count of data points in each class:")
display(df['class'].value_counts())
# Out:
# Count of data points in each class:
# class
# 2    180
# 3    173
# 1     87
# Name: count, dtype: int64

# %%
# Install imblearn
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# Apply SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)

# Display the new class distribution
print("Count of data points in each class after SMOTE:")
display(pd.Series(y_resampled).value_counts())
# Out:
# Count of data points in each class after SMOTE:
# class
# 2    180
# 1    180
# 3    180
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Split the resampled data into training and testing sets (80/20 split)
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

print("Shape of original DataFrame:", df.shape)
print("Shape of resampled data after SMOTE:", X_resampled.shape)
print("Shape of training set:", X_train.shape)
print("Shape of testing set:", X_test.shape)
# Out:
# Shape of original DataFrame: (440, 8)
# Shape of resampled data after SMOTE: (540, 7)
# Shape of training set: (432, 7)
# Shape of testing set: (108, 7)

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=42)

# %%
from sklearn.model_selection import train_test_split

# Split the resampled data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

# Display the shapes of the resulting sets
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (432, 7)
# Shape of X_test: (108, 7)
# Shape of y_train: (432,)
# Shape of y_test: (108,)

# %%
print("Variance of each feature:")
display(X.var())
# Out:
# Variance of each feature:
# Region              5.994978e-01
# Fresh               1.599549e+08
# Milk                5.446997e+07
# Grocery             9.031010e+07
# Frozen              2.356785e+07
# Detergents_Paper    2.273244e+07
# Delicassen          7.952997e+06
# dtype: float64

# %%
# Set pandas display option to show more decimal places
pd.set_option('display.float_format', '{:.6f}'.format)

print("Variance of each feature:")
display(X.var())

# Reset pandas display option to default
pd.reset_option('display.float_format')
# Out:
# Variance of each feature:
# Region                     0.599498
# Fresh              159954927.421407
# Milk                54469967.238926
# Grocery             90310103.754380
# Frozen              23567853.166183
# Detergents_Paper    22732436.036400
# Delicassen           7952997.497986
# dtype: float64

# %%
# Remove the column with the least variance from the resampled features
# 'Region' was the first column (index 0) in the original X
X_resampled = np.delete(X_resampled, 0, axis=1)

# Display the shape of the data after removing the column
print("Shape of resampled data after removing the column with least variance:", X_resampled.shape)
# Out:
# Shape of resampled data after removing the column with least variance: (540, 6)

# %%
# Calculate the Pearson correlation matrix
correlation_matrix = df.corr(method='pearson')

# Display the correlation matrix
print("Pearson Correlation Matrix:")
display(correlation_matrix)
# Out:
# Pearson Correlation Matrix:
#                     Region     Fresh      Milk   Grocery    Frozen  \
# Region            1.000000  0.055287  0.032288  0.007696 -0.021044
# Fresh             0.055287  1.000000  0.100510 -0.011854  0.345881
# Milk              0.032288  0.100510  1.000000  0.728335  0.123994
# Grocery           0.007696 -0.011854  0.728335  1.000000 -0.040193
# Frozen           -0.021044  0.345881  0.123994 -0.040193  1.000000
# Detergents_Paper -0.001483 -0.101953  0.661816  0.924641 -0.131525
# Delicassen        0.045212  0.244690  0.406368  0.205497  0.390947
# class            -0.038396 -0.390320 -0.113982 -0.125400 -0.102664
#
#                   Detergents_Paper  Delicassen     class
# Region                   -0.001483    0.045212 -0.038396
# Fresh                    -0.101953    0.244690 -0.390320
# Milk                      0.661816    0.406368 -0.113982
# Grocery                   0.924641    0.205497 -0.125400
# ...

# %%
from sklearn.model_selection import train_test_split

# Split the resampled data into training and testing sets (80/20 split)
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

# Display the shapes of the resulting sets
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (432, 6)
# Shape of X_test: (108, 6)
# Shape of y_train: (432,)
# Shape of y_test: (108,)

# %%
def knn(X, y, queryPoint, k):
    """Predict the class label for the query point"""
    # Euclidean Distance
    dist = np.sqrt(np.sum((queryPoint - X)**2, axis=1))

    # Storing distance and class labels together
    # Use y.iloc[i] to access elements by integer position
    distances = [(dist[i], y.iloc[i]) for i in range(len(dist))]

    # sort the distances
    distances = sorted(distances)
    # Nearest/First k points
    distances = distances[:k]

    distances = np.array(distances)

    classes_counts = np.unique(distances[:,1], return_counts=True)

    index = classes_counts[1].argmax()
    pred = classes_counts[0][index]

    return int(pred), distances

# %%
pred,neighbors = knn(X_train, y_train, X_test[50],5)

print(f'k nearest neighbors with the distance and class label :{neighbors}')

print(f'The predicted class label: {pred}')
# Out:
# k nearest neighbors with the distance and class label :[[0.28280531 1.        ]
#  [0.31608592 1.        ]
#  [0.32088363 1.        ]
#  [0.33576108 1.        ]
#  [0.33627553 1.        ]]
# The predicted class label: 1

# %%
from sklearn.metrics import classification_report

# Make predictions using the custom knn function
y_pred = [knn(X_train, y_train, X_test[i], k=5)[0] for i in range(len(X_test))]

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.92      0.94      0.93        36
#            2       1.00      0.86      0.93        36
#            3       0.88      0.97      0.92        36
#
#     accuracy                           0.93       108
#    macro avg       0.93      0.93      0.93       108
# weighted avg       0.93      0.93      0.93       108
